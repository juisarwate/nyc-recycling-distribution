# %% [markdown]
# # Recycling Distribution in NYC FY 2011-21
#
# ### I was interested in taking a look at the distribution and variety of reclycling collected by the NYC Department of Sanitation and through programs partnered with DSNY.
#
# The story that I will be exploring is a breakdown of different kinds of collections of recycling in NYC. There are Department of Sanitation-conducted collections and non-DS collection methods from businesses and individuals for which there is collection data. I also want to map the different collection centers and which entities can recycle there.

# %%
import pandas as pd
from plotnine import *

pd.set_option("display.max_columns", None)

# %% [markdown]
# ### This is looking at average daily tons of recycling per fiscal year.

# %%
df = pd.read_excel('DSNY_and_NonDSNY_Collections_by_Fiscal_Year.xlsx', sheet_name='Sheet1',
              keep_default_na=False, na_values=['_'])
df.head()
# Out:
#    fiscal_year  paper_cardboard_DSNY  metal_glass_plastic_DSNY  organics_DSNY  \
# 0         2011                1062.0                     714.0            1.0
# 1         2012                1028.0                     706.0            4.0
# 2         2013                1015.0                     699.0            9.2
# 3         2014                1007.0                     748.0           19.0
# 4         2015                1018.0                     784.0           43.0
#
#   lot_metal_bulk_DSNY  other_metal_bulk_DSNY  rikers_food_waste_DSNY  \
# 0                 0.5                   8.60                    8.20
# 1                 N/A                  10.83                    5.88
# 2                 N/A                  17.00                    6.00
# 3                 N/A                  38.00                    6.00
# 4                 N/A                  42.00                    5.00
#
#    harmful_products_DSNY hard_cover_removals_DSNY redeemed_bottles_cans_Indiv  \
# ...
